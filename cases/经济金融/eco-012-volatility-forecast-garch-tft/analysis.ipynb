# %% [markdown]
# # 波动率预测：GARCH族模型与Temporal Fusion Transformer对比
#
# Case ID: eco-012-volatility-forecast-garch-tft
#
# Method tags: GARCH, EGARCH, Temporal Fusion Transformer, Volatility Forecasting
#
# This notebook only wraps the script-driven workflow in nalysis.py.
# Do not add standalone business logic here.

# %%
# %run ./analysis.py --smoke-test

# %% [markdown]
# ## Notes
#
# Use markdown cells for narrative, interpretation, and presentation only.
