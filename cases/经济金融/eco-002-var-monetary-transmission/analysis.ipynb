# %% [markdown]
# # 货币政策传导机制：基于VAR模型的脉冲响应分析
#
# - case_id: `eco-002-var-monetary-transmission`
# - 方法标签：VAR / IRF / FEVD
# - 该 notebook 只调用 `analysis.py` 并展示脚本生成的结果，不承载独立建模逻辑。

# %% [markdown]
# ## 运行脚本真源
#
# 脚本会生成模拟宏观时间序列、执行平稳化说明、选择 VAR 滞后阶数，并输出 IRF 与 FEVD 图表。

# %%
# %run ./analysis.py

# %% [markdown]
# ## 文字摘要
#
# 这里直接读取脚本生成的摘要文件，保持叙事和脚本输出同步。

# %%
from pathlib import Path
print((Path('outputs') / 'summary.txt').read_text('utf-8'))

# %% [markdown]
# ## 图表展示与解读
#
# - `irf_m2_shock.png` 用于查看 M2 冲击对价格、投资、消费与汇率的动态影响。
# - `fevd_overview.png` 用于比较不同变量的预测误差方差来源。
# - 解读时要记住：本案例的冲击排序和冲击识别都是教学设定，而不是央行结构冲击估计。

# %%
from pathlib import Path
from IPython.display import Image, display
display(Image((Path('outputs') / 'irf_m2_shock.png').read_bytes()))
display(Image((Path('outputs') / 'fevd_overview.png').read_bytes()))
