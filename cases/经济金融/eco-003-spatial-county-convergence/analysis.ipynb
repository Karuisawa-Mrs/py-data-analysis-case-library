# %% [markdown]
# # 中国县域经济收敛性：空间杜宾模型分析
#
# **case_id**: eco-003-spatial-county-convergence
#
# **method_tags**: Moran's I, SDM, LISA
#
# This notebook is only a narrative wrapper around `analysis.py`.

# %%
# %run ./analysis.py --smoke-test

# %% [markdown]
# ## Notes
#
# All reusable logic lives in `analysis.py`; keep this notebook presentation-only.
