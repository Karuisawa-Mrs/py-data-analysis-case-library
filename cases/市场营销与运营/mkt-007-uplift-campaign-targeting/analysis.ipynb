# %% [markdown]
# # 精准营销中的增量响应建模：客户 uplift 分析
#
# - case_id: `mkt-007-uplift-campaign-targeting`
# - method tags: `Uplift Modeling`, `CATE`
# - notebook 只调用 `analysis.py`，不承载独立业务逻辑。

# %% [markdown]
# ## 运行脚本真源
#
# 下面的代码单元直接调用 `analysis.py` 中的封装接口，生成模拟数据、uplift 排名和 ROI 对比表。

# %%
from analysis import run_case
artifacts = run_case()

# %%
from analysis import print_notebook_summary
print_notebook_summary()

# %% [markdown]
# ## 解释提示
#
# 若 `roi_comparison.csv` 中 uplift 策略在相同预算下的 `expected_profit` 高于 response 策略，说明模型成功区分了‘本来就会买’与‘因为营销才会买’。
