# %% [markdown]
# # 电信客户流失预测：逻辑回归与梯度提升树对比
#
# - case_id: `mkt-008-churn-prediction-benchmark`
# - method_tags: `Binary Classification`, `Logistic Regression`, `Gradient Boosting`
#
# 本 notebook 只调用 `analysis.py`，不承载独立分析逻辑。

# %%
# %run ./analysis.py --smoke-test

# %% [markdown]
# ## 说明
#
# 如需完整输出，请在终端运行 `python analysis.py`。
