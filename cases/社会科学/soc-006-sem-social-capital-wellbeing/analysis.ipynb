# %% [markdown]
# # 社会资本如何影响主观幸福感：结构方程模型的路径分析
#
# **case_id**: soc-006-sem-social-capital-wellbeing
#
# **method_tags**: SEM, CFA, Mediation
#
# 本 notebook 只调用 `analysis.py`，不承载独立分析逻辑。

# %%
# %run ./analysis.py --smoke-test

# %% [markdown]
# ## 说明
#
# 如需完整输出，请在终端运行 `python analysis.py`。
