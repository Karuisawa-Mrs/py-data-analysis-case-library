# %% [markdown]
# # 父母外出务工对留守儿童学业成绩的影响：双向固定效应模型
#
# - case_id: `soc-004-twfe-left-behind-education`
# - 方法标签：`TWFE`、`Panel Regression`
# - 该 notebook 只包装 `analysis.py`，不承载独立回归逻辑。

# %% [markdown]
# ## Notebook 用途
#
# 本案例通过学生固定效应和年份固定效应解释面板识别逻辑：
# - 学生固定效应吸收不随时间变化的个体差异；
# - 年份固定效应吸收所有学生共同面对的宏观和教育制度冲击。

# %%
# %run ./analysis.py --smoke-test

# %%
# %run ./analysis.py
