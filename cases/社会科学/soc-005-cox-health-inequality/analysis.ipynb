# %% [markdown]
# # 社会经济地位对健康预期寿命的影响：Cox比例风险模型
#
# **case_id**: soc-005-cox-health-inequality
#
# **method_tags**: Survival Analysis, Cox, Kaplan-Meier
#
# 本 notebook 只调用 `analysis.py`，不承载独立分析逻辑。

# %%
# %run ./analysis.py --smoke-test

# %% [markdown]
# ## 说明
#
# 如需完整输出，请在终端运行 `python analysis.py`。
